# %% [markdown]
# <a href="https://colab.research.google.com/github/hellogity/catower/blob/main/%EC%B2%98%EC%9D%8C%20%EC%8D%A8%EB%B3%B4%EB%8A%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('stopwords')

import string
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

text = open('/content/romeo_and_juliet.txt', encoding='utf-8').read()

wc = WordCloud(width=800, height=400, stopwords=set(stopwords.words('english'))).generate(text)

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
